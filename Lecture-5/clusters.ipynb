# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mean1 = [4,4]
covar1 = [[1,-1], [-1,5]]

mean2 = [-1,-1]
covar2 = [[1,0], [0,1]]

# %%
d1 = np.random.multivariate_normal(mean1, covar1, 1000)
d2 = np.random.multivariate_normal(mean2, covar2, 1000)

# %%
d1.shape
d1
# Out:
# array([[4.54711016, 2.58362507],
#        [5.27926412, 3.08373009],
#        [4.32483886, 8.06057142],
#        ...,
#        [5.16097875, 3.30760847],
#        [3.30639832, 4.65498761],
#        [2.82628501, 6.64473996]])

# %%
plt.scatter(d1[:,0], d1[:,1])

# %%
d1[:, 0].shape
# Out:
# (1000,)

# %%
plt.figure()
plt.scatter(d1[:, 0], d1[:, 1], label="cluster-1")
plt.scatter(d2[:, 0], d2[:, 1], label="cluster-2")
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel("longitude")
plt.ylabel("latitube")
plt.title("Poore 20 number")
plt.legend()
plt.show()

# %%
np.var(d1[:, 0])
# Out:
# 1.047426519249974

# %%
d1.shape
# Out:
# (1000, 2)

# %%
X = np.vstack([d1, d2])  # THIS IS NOT X-AXIS, we merged both the points d1 and d2

y = np.ones([len(d1) + len(d2)], dtype=int)
y[len(d2):] = 2

# %%
# y   # this will be used for coloring, THIS IS NOT Y-AXIS

# %%
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y) # c means color is y
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel("longitude")
plt.ylabel("latitube")
plt.title("Poore 20 number")
plt.show()

# %%
! python3 -m pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/e9/57/8a9889d49d0d77905af5a7524fb2b468d2ef5fc723684f51f5ca63efed0d/scikit_learn-0.21.3-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (10.5MB)
#     100% |████████████████████████████████| 10.5MB 685kB/s ta 0:00:011
# Collecting joblib>=0.11 (from scikit-learn)
#   Downloading https://files.pythonhosted.org/packages/cd/c1/50a758e8247561e58cb87305b1e90b171b8c767b15b12a1734001f41d356/joblib-0.13.2-py2.py3-none-any.whl (278kB)
#     100% |████████████████████████████████| 286kB 604kB/s ta 0:00:01
# Collecting scipy>=0.17.0 (from scikit-learn)
#   Downloading https://files.pythonhosted.org/packages/d5/06/1a696649f4b2e706c509cb9333fdc6331fbe71251cede945f9e1fa13ea34/scipy-1.3.1-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (27.7MB)
#     100% |████████████████████████████████| 27.7MB 955kB/s ta 0:00:011   46% |██████████████▉                 | 12.8MB 1.8MB/s eta 0:00:09
# Requirement already satisfied: numpy>=1.11.0 in /miniconda3/lib/python3.7/site-packages (from scikit-learn) (1.15.4)
# Installing collected packages: joblib, scipy, scikit-learn
# Successfully installed joblib-0.13.2 scikit-learn-0.21.3 scipy-1.3.1
# You are using pip version 19.0.3, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=1000, centers=2) # random_state=0 means will show same everytime you run it
# will take sd and mean by it's own, just to create random clusters in a simple way
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y) # c means color is y
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.show()
