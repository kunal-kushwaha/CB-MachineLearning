# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mean1 = [4,4]
covar1 = [[1,-1], [-1,5]]

mean2 = [-1,-1]
covar2 = [[1,0], [0,1]]

# %%
d1 = np.random.multivariate_normal(mean1, covar1, 1000)
d2 = np.random.multivariate_normal(mean2, covar2, 1000)

# %%
d1.shape
d1
# Out:
# array([[1.71158166, 9.42340219],
#        [4.49005524, 6.77157681],
#        [4.33185026, 2.16393619],
#        ...,
#        [3.81913903, 3.85434689],
#        [2.12835455, 4.17488357],
#        [3.60999872, 3.26048168]])

# %%
plt.scatter(d1[:,0], d1[:,1])

# %%
d1[:, 0].shape
# Out:
# (1000,)

# %%
plt.figure()
plt.scatter(d1[:, 0], d1[:, 1], label="cluster-1")
plt.scatter(d2[:, 0], d2[:, 1], label="cluster-2")
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel("longitude")
plt.ylabel("latitube")
plt.title("Poore 20 number")
plt.legend()
plt.show()

# %%
np.var(d1[:, 0])
# Out:
# 0.9853552631030277

# %%
d1.shape
# Out:
# (1000, 2)

# %%
X = np.vstack([d1, d2])  # THIS IS NOT X-AXIS, we merged both the points d1 and d2

y = np.ones([len(d1) + len(d2)], dtype=int)
y[len(d2):] = 2

# %%
# y   # this will be used for coloring, THIS IS NOT Y-AXIS

# %%
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y) # c means color is y
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.xlabel("longitude")
plt.ylabel("latitube")
plt.title("Poore 20 number")
plt.show()

# %%
! python3 -m pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (0.21.3)
# Requirement already satisfied: scipy>=0.17.0 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: joblib>=0.11 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from scikit-learn) (0.14.0)
# Requirement already satisfied: numpy>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from scikit-learn) (1.17.2)
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=1000, centers=2) # random_state=0 means will show same everytime you run it
# will take sd and mean by it's own, just to create random clusters in a simple way
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=y) # c means color is y
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.show()

X[:,0].std(), X[:,0].mean()
# Out:
# (1.2447669338232765, -1.4055579469316382)
